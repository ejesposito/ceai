# %%
import random
import gym
import numpy as np
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Lambda
from tensorflow.keras.optimizers import Adam, RMSprop
import sklearn.preprocessing
from lib import plotting
from PIL import Image

ENV_NAME = "Pong-v0"
#ENV_NAME = "BreakoutNoFrameskip-v4"

env = gym.make(ENV_NAME)

# fuentes:
# https://github.com/rohitgirdhar/Deep-Q-Networks/
# https://github.com/keon/deep-q-learning/blob/master/dqn.py
# https://github.com/AdamStelmaszczyk/dqn/
# Out:
# Using TensorFlow backend.

# %%
class Estimator():
    """
    Red Neuronal que aproxima la función de valor estado acción (q-function)
    """   
    def __init__(self, env, frame_history=4, learning_rate=0.001):        
        n_actions = env.action_space.n
        obs_shape = (84,84,frame_history)
        model = Sequential()
        model.add(Lambda(lambda x: x / 255.0))
        
        #se define una red convolucional
        model.add(Conv2D(16, 8, strides=(4, 4),activation='relu',input_shape=obs_shape))
        model.add(Conv2D(32, 4, strides=(2, 2),activation='relu'))
        model.add(Flatten())
        model.add(Dense(32, activation='relu'))
        model.add(Dense(n_actions, activation=None))
        
        # para la red convolucional como la utilizada en el paper de DeepMind descomentar
        # (https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf)
        #model = Sequential()
        #model.add(Lambda(lambda x: x / 255.0))
        #model.add(Conv2D(32, 8, strides=(4, 4),activation='relu',input_shape=obs_shape))
        #model.add(Conv2D(64, 4, strides=(2, 2),activation='relu'))
        #model.add(Conv2D(64, 3, strides=(1, 1),activation='relu'))
        #model.add(Flatten())
        #model.add(Dense(512, activation='relu'))
        #model.add(Dense(n_actions, activation=None))
        
        model.compile(loss="mse", optimizer=RMSprop(learning_rate, rho=0.95, epsilon=0.01))
        self.model = model
     
    def update(self, states, q_values, verbose=0):
        """
        Realiza un update de los parámetros de la red neuronal usando un batch de estados y batch de vectores de valores
        de la función estado-acción correspondientes
        """
        self.model.fit(states, q_values, verbose=0)
    
    def predict(self, s):
        """
        Realiza una predicción de la función de valor estado-accion dado el estado
        
        Argumentos:
            s: estado para el cual realizar la predicción
            
        Retorna:
            Un vector con la predicción de la función de valor para todas las accións
        """
        return self.model.predict(self.process_state_for_network(s))
    
    def process_state_for_network(self, state):
        """Scale, convert to greyscale and store as float32.
        Basically same as process state for memory, but this time
        outputs float32 images.
        """
        state = state.astype('float')
        return state

class Memory():
    def __init__(self, memory_size=100000, history_length=4):
        self.history = np.zeros((84, 84, history_length))
        self.history_length = history_length
        self.memory = deque(maxlen=memory_size)
    
    def remember(self, state, action, reward, next_state, done):
        """
        Guardar una tupla de estado, accion, recompensa, proximo estado, estado_terminal.
        """
        self.memory.append((state, action, reward, next_state, done))
        
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def preprocess_image(self, state):
        """
        Convertir la imagen a blanco y negro y reducirla a 84x84.
        """
        I = Image.fromarray(state, 'RGB')
        I = I.convert('L')  # to gray
        I = I.resize((84, 84), Image.ANTIALIAS)
        I = np.array(I).astype('uint8')
        return I
    
    def push_frame(self, state):
        """
        Pushear el frame a la stack de frames.
        """
        state = self.preprocess_image(state)
        self.history[..., 0] = state
        self.history = np.roll(self.history, -1, axis=-1)
        return self.history.copy()
    
    def reset_history(self):
        """
        Resetear el stack de frames.
        """
        self.history = np.zeros((84, 84, self.history_length))
    
    def __len__(self):
        return len(self.memory)

# %%
class Learner:
    def __init__(self, env, estimator, estimator_target, num_steps, discount_factor=1.0, 
                 exploration_max=1.0, exploration_min=0.05, epsilon_decay=0.99, memory_size=100000, 
                 batch_size=64, target_update_freq=1000, history_length=4, train_freq=4, burnin=100000,
                 save_freq = 50000):
        """
        Algoritmo q-learning/sarsa con experience replay utilizando aproximación de funciones.

        Argumentos de inicialización:
            env: ambiente de OpenAI.
            estimator: función de aproximación de la función de valor estado-acción.
            estimator_target: función de aproximación target de la función de valor estado-acción.
            num_steps: número de pasos durante los cuales entrenar el estimador.
            discount_factor: factor de descuento gama.
            exploration_max: probabilidad de tomar una acción aleatoria inicialmente.
            exploration_min: mínima probabilidad de tomar una acción aleatoria.
            epsilon_decay: luego de cada episodio la probabilidad de una acción aleatoria decae por este factor.
            target_update_freq: frecuencia de update de la función de aproximación target.
            train_freq: frecuencia de entrenamiento de la función de aproximación de la función de valor.
            history_length: cantidad de frames que se mandan a la red neuronal.
            burnin: cantidad inicial de pasos exploratorios para tener la memoria inicializada.
            save_freq: cada cuántos pasos se guardan los modelos.
        """
        self.env = env
        self.discount_factor = discount_factor
        
        self.estimator = estimator
        self.estimator_target = estimator_target
        
        self.num_steps = num_steps
        
        self.exploration_rate = exploration_max
        self.exploration_min = exploration_min
        self.epsilon_decay = epsilon_decay
        self.train_freq = train_freq
        self.batch_size = batch_size
        self.target_update_freq = target_update_freq
        
        self.memory = Memory(memory_size, history_length)
        
        self.history_length = history_length
        
        self.burnin = burnin
        self.save_freq = save_freq
        
        
    def decay_exploration_rate(self):
        # decae la probabilidad de exploración
        self.exploration_rate *= self.epsilon_decay
        self.exploration_rate = max(self.exploration_min, self.exploration_rate)
    
    def policy_fn(self, state, epsilon):
        """
        Política epsilon-greedy basada en la función de aproximación actual y la probabilidad de exploración epsilon.

        Retorna:
            Un vector con la probabilidad de tomar cada acción.
        """
        A = np.ones(env.action_space.n, dtype=float) * self.exploration_rate / env.action_space.n
        q_values = self.estimator.predict(state)
        best_action = np.argmax(q_values[0])
        A[best_action] += (1.0 - epsilon)
        return A
    
    def experience_replay(self):
        """
        Realiza una corrida de entrenamiento de la función de aproximación dado un batch de experiencia acumulada.
        """
        if len(self.memory) < self.batch_size:
            return
        # samplear de la memoria
        batch = self.memory.sample(self.batch_size)
        
        batch_q_values = np.zeros((self.batch_size, self.env.action_space.n))
        batch_states = np.zeros((self.batch_size, 84, 84, self.history_length))
        
        for i_batch, (state, action, reward, next_state, terminal) in enumerate(batch):
            
            q_update = reward
            if not terminal:
                ## el update de q-learning para este ejemplo
                q_update = reward + self.discount_factor * np.amax(self.estimator_target.predict(next_state)[0])
            
            q_values = self.estimator.predict(state)
            q_values[0][action] = q_update
            batch_q_values[i_batch] = q_values
            batch_states[i_batch] = state
            i_batch += 1
        
        # un paso en la dirección del gradiente
        self.estimator.update(batch_states, batch_q_values, verbose=0)
        
    def train(self):    
        """
        Realiza Q-Learning o Sarsa con aproximación de la función de valor estado-acción.
        Retorna:
            Un objeto de tipo EpisodeStats con dos arrays de numpy para la longitud y recompensa acumulada de cada
            episodio respectivamente.
        """
        stats = plotting.EpisodeStats(
            episode_lengths=[],
            episode_rewards=[])    
        
        # realizamos self.burnin pasos iniciales de exploración para inicializar la memoria
        itr = 0
        while itr <= self.burnin:
            step = 0
            self.memory.reset_history()
            state = env.reset()
            # guardar en el stack de frames
            state = self.memory.push_frame(state)
            # hacer un reshape del estado para poder pasarlo por la red neronal
            state = np.reshape(state, [1, 84, 84, self.history_length])
            # resetear el reward
            cum_reward = 0.0
            # elegir acción al azar
            action = np.random.choice(self.env.action_space.n)
            while True:
                env.render()
                # tomar la acción elegida
                next_state, reward, terminal, info = env.step(action)
                cum_reward += reward*self.discount_factor**step
                # guardar en el stack de frames
                next_state = self.memory.push_frame(next_state)
                itr += 1; step += 1
                # hacer un reshape del estado para poder pasarlo por la red neronal
                next_state = np.reshape(next_state, [1, 84, 84, self.history_length])
                # elegir la próxima acción al azar
                if not terminal:
                    next_action = np.random.choice(self.env.action_space.n)
                else:
                    next_action = None
                    self.memory.reset_history()
                # almacenar en la memoria
                self.memory.remember(state, action, reward, next_state, terminal)
                # actualizar estado y acción
                state = next_state; action = next_action
                if terminal:
                    print("Iteración de burnin:" + str(itr) + 
                          ", Exploración: " + str(self.exploration_rate) + 
                          ", Recompensa Acumulada: " + str(cum_reward))
                    break
        
        # comienza el loop de entrenamiento
        itr = 0
        step = 0
        n_episode = 0 
        while itr <=  self.num_steps:
            # resetear el stack de frames (nuevo episodio)
            self.memory.reset_history()
            state = env.reset()
            # guardar en el stack de frames
            state = self.memory.push_frame(state)
            # hacer un reshape del estado para poder pasarlo por la red neronal
            state = np.reshape(state, [1, 84, 84, self.history_length])
            cum_reward = 0.0    
            # elegir la acción
            action = np.random.choice(self.env.action_space.n, p=self.policy_fn(state, self.exploration_rate))
            while True:
                env.render()
                # realizar un paso con la acción elegida
                next_state, reward, terminal, info = env.step(action)
                # acumular la recompensa
                cum_reward += reward*self.discount_factor**step
                # guardar en el stack de frames
                next_state = self.memory.push_frame(next_state)
                itr += 1; step += 1
                # hacer un reshape del estado para poder pasarlo por la red nueronal
                next_state = np.reshape(next_state, [1, 84, 84, self.history_length])
                if not terminal:
                    # elegir la próxima acción
                    next_action = np.random.choice(self.env.action_space.n, p=self.policy_fn(next_state, self.exploration_rate))
                else:
                    next_action = None
                    self.memory.reset_history()
                
                self.memory.remember(state, action, reward, next_state, terminal)
                # actualizar el estado y la acción
                state = next_state; action = next_action
                if terminal:
                    print("Episodio: " + str(n_episode) + 
                          ", Iteración:" + str(itr) + 
                          ", Exploración: " + str(self.exploration_rate) + 
                          ", Recompensa Acumulada: " + str(cum_reward))
                    # Actualizar estadísticas
                    stats.episode_rewards.append(cum_reward)
                    stats.episode_lengths.append(step)
                    break        
                    
                # copiar los pesos de la red siendo entrenada al target
                if itr % self.target_update_freq == 0:
                    self.estimator_target.model.set_weights(self.estimator.model.get_weights())
                # entrenar la red cada train_freq steps
                if itr % self.train_freq == 0:
                    self.experience_replay()
                # guardar la red nueronal
                if itr % self.save_freq == 0:
                    self.estimator.model.save("model_" + str(itr) + ".h5")
            # decaer la probabilidad de exploración
            self.decay_exploration_rate()
            n_episode += 1
        return stats

# %%
estimator = Estimator(env)
estimator_target = Estimator(env)
learner = Learner(env, estimator, estimator_target, 1000000)
# Out:
# WARNING:tensorflow:From /home/javkrei/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
stats = learner.train()
# Out:
# Iteración de burnin:1027, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:2271, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:3564, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:4870, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:6398, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:7833, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:8985, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:10174, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:11450, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:12925, Exploración: 1.0, Recompensa Acumulada: -18.0
# Iteración de burnin:13995, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:15091, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:16440, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:17737, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:19162, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:20369, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:21613, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:22841, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:24013, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:25585, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:26677, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:27997, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:29010, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:30175, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:31423, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:32839, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:34159, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:35456, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:36479, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:37776, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:39110, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:40126, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:41374, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:42621, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:43899, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:45070, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:46319, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:47599, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:49098, Exploración: 1.0, Recompensa Acumulada: -18.0
# Iteración de burnin:50241, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:51780, Exploración: 1.0, Recompensa Acumulada: -18.0
# Iteración de burnin:52955, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:54412, Exploración: 1.0, Recompensa Acumulada: -18.0
# Iteración de burnin:55527, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:56778, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:58091, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:59338, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:60653, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:61944, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:63194, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:64446, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:65547, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:66751, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:68109, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:69295, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:70316, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:71426, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:72630, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:74147, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:75227, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:76450, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:78167, Exploración: 1.0, Recompensa Acumulada: -17.0
# Iteración de burnin:79297, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:80623, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:81800, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:82984, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:84187, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:85366, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:86622, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:87821, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:88917, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:90257, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:91660, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:92974, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:94077, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:95100, Exploración: 1.0, Recompensa Acumulada: -21.0
# Iteración de burnin:96640, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:97861, Exploración: 1.0, Recompensa Acumulada: -20.0
# Iteración de burnin:99319, Exploración: 1.0, Recompensa Acumulada: -19.0
# Iteración de burnin:100445, Exploración: 1.0, Recompensa Acumulada: -20.0
# WARNING:tensorflow:From /home/javkrei/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Episodio: 0, Iteración:1223, Exploración: 1.0, Recompensa Acumulada: -21.0
# Episodio: 1, Iteración:2453, Exploración: 0.99, Recompensa Acumulada: -20.0
# Episodio: 2, Iteración:3624, Exploración: 0.9801, Recompensa Acumulada: -20.0
# Episodio: 3, Iteración:4827, Exploración: 0.9702989999999999, Recompensa Acumulada: -21.0
# Episodio: 4, Iteración:6056, Exploración: 0.96059601, Recompensa Acumulada: -20.0
# Episodio: 5, Iteración:7234, Exploración: 0.9509900498999999, Recompensa Acumulada: -21.0
# Episodio: 6, Iteración:8312, Exploración: 0.9414801494009999, Recompensa Acumulada: -21.0
# Episodio: 7, Iteración:9403, Exploración: 0.9320653479069899, Recompensa Acumulada: -21.0
# Episodio: 8, Iteración:10697, Exploración: 0.92274469442792, Recompensa Acumulada: -19.0
# Episodio: 9, Iteración:11975, Exploración: 0.9135172474836407, Recompensa Acumulada: -20.0
# Episodio: 10, Iteración:13135, Exploración: 0.9043820750088043, Recompensa Acumulada: -21.0
# Episodio: 11, Iteración:14368, Exploración: 0.8953382542587163, Recompensa Acumulada: -21.0
# Episodio: 12, Iteración:15697, Exploración: 0.8863848717161291, Recompensa Acumulada: -20.0
# Episodio: 13, Iteración:16908, Exploración: 0.8775210229989678, Recompensa Acumulada: -20.0
# Episodio: 14, Iteración:18418, Exploración: 0.8687458127689781, Recompensa Acumulada: -20.0
# Episodio: 15, Iteración:19437, Exploración: 0.8600583546412883, Recompensa Acumulada: -21.0
# Episodio: 16, Iteración:20543, Exploración: 0.8514577710948754, Recompensa Acumulada: -21.0
# Episodio: 17, Iteración:21676, Exploración: 0.8429431933839266, Recompensa Acumulada: -21.0
# Episodio: 18, Iteración:22880, Exploración: 0.8345137614500874, Recompensa Acumulada: -21.0
# Episodio: 19, Iteración:24183, Exploración: 0.8261686238355865, Recompensa Acumulada: -20.0
# Episodio: 20, Iteración:25474, Exploración: 0.8179069375972307, Recompensa Acumulada: -21.0
# Episodio: 21, Iteración:26825, Exploración: 0.8097278682212583, Recompensa Acumulada: -20.0
# Episodio: 22, Iteración:28144, Exploración: 0.8016305895390458, Recompensa Acumulada: -19.0
# Episodio: 23, Iteración:29398, Exploración: 0.7936142836436553, Recompensa Acumulada: -20.0
# Episodio: 24, Iteración:30446, Exploración: 0.7856781408072188, Recompensa Acumulada: -21.0
# Episodio: 25, Iteración:32047, Exploración: 0.7778213593991465, Recompensa Acumulada: -18.0
# Episodio: 26, Iteración:33080, Exploración: 0.7700431458051551, Recompensa Acumulada: -21.0
# Episodio: 27, Iteración:34260, Exploración: 0.7623427143471035, Recompensa Acumulada: -21.0
# Episodio: 28, Iteración:35401, Exploración: 0.7547192872036325, Recompensa Acumulada: -21.0
# Episodio: 29, Iteración:36806, Exploración: 0.7471720943315961, Recompensa Acumulada: -21.0
# Episodio: 30, Iteración:38050, Exploración: 0.7397003733882802, Recompensa Acumulada: -21.0
# Episodio: 31, Iteración:39380, Exploración: 0.7323033696543974, Recompensa Acumulada: -20.0
# Episodio: 32, Iteración:40478, Exploración: 0.7249803359578534, Recompensa Acumulada: -21.0
# Episodio: 33, Iteración:41513, Exploración: 0.7177305325982748, Recompensa Acumulada: -21.0
# Episodio: 34, Iteración:42887, Exploración: 0.7105532272722921, Recompensa Acumulada: -19.0
# Episodio: 35, Iteración:44016, Exploración: 0.7034476949995692, Recompensa Acumulada: -20.0
# Episodio: 36, Iteración:45118, Exploración: 0.6964132180495735, Recompensa Acumulada: -21.0
# Episodio: 37, Iteración:46346, Exploración: 0.6894490858690777, Recompensa Acumulada: -20.0
# Episodio: 38, Iteración:47445, Exploración: 0.682554595010387, Recompensa Acumulada: -21.0
# Episodio: 39, Iteración:48783, Exploración: 0.6757290490602831, Recompensa Acumulada: -19.0
# Episodio: 40, Iteración:50048, Exploración: 0.6689717585696803, Recompensa Acumulada: -19.0
# Episodio: 41, Iteración:51073, Exploración: 0.6622820409839835, Recompensa Acumulada: -21.0
# Episodio: 42, Iteración:52207, Exploración: 0.6556592205741436, Recompensa Acumulada: -20.0
# Episodio: 43, Iteración:53343, Exploración: 0.6491026283684022, Recompensa Acumulada: -21.0
# Episodio: 44, Iteración:54473, Exploración: 0.6426116020847181, Recompensa Acumulada: -21.0
# Episodio: 45, Iteración:55613, Exploración: 0.6361854860638709, Recompensa Acumulada: -21.0
# Episodio: 46, Iteración:56875, Exploración: 0.6298236312032323, Recompensa Acumulada: -20.0
# Episodio: 47, Iteración:57874, Exploración: 0.6235253948912, Recompensa Acumulada: -21.0
# Episodio: 48, Iteración:58901, Exploración: 0.617290140942288, Recompensa Acumulada: -21.0
# Episodio: 49, Iteración:60104, Exploración: 0.6111172395328651, Recompensa Acumulada: -20.0
# Episodio: 50, Iteración:61138, Exploración: 0.6050060671375365, Recompensa Acumulada: -21.0
# Episodio: 51, Iteración:62318, Exploración: 0.5989560064661611, Recompensa Acumulada: -21.0
# Episodio: 52, Iteración:63341, Exploración: 0.5929664464014994, Recompensa Acumulada: -21.0
# Episodio: 53, Iteración:64494, Exploración: 0.5870367819374844, Recompensa Acumulada: -21.0
# Episodio: 54, Iteración:65619, Exploración: 0.5811664141181095, Recompensa Acumulada: -21.0
# Episodio: 55, Iteración:66857, Exploración: 0.5753547499769285, Recompensa Acumulada: -20.0
# Episodio: 56, Iteración:68330, Exploración: 0.5696012024771592, Recompensa Acumulada: -19.0
# Episodio: 57, Iteración:69519, Exploración: 0.5639051904523876, Recompensa Acumulada: -21.0
# Episodio: 58, Iteración:70781, Exploración: 0.5582661385478638, Recompensa Acumulada: -21.0
# Episodio: 59, Iteración:71800, Exploración: 0.5526834771623851, Recompensa Acumulada: -21.0
# Episodio: 60, Iteración:72826, Exploración: 0.5471566423907612, Recompensa Acumulada: -21.0
# Episodio: 61, Iteración:73829, Exploración: 0.5416850759668536, Recompensa Acumulada: -21.0
# Episodio: 62, Iteración:75162, Exploración: 0.536268225207185, Recompensa Acumulada: -20.0
# Episodio: 63, Iteración:76272, Exploración: 0.5309055429551132, Recompensa Acumulada: -21.0
# Episodio: 64, Iteración:77417, Exploración: 0.525596487525562, Recompensa Acumulada: -21.0
# Episodio: 65, Iteración:78818, Exploración: 0.5203405226503064, Recompensa Acumulada: -20.0
# Episodio: 66, Iteración:80042, Exploración: 0.5151371174238033, Recompensa Acumulada: -20.0
# Episodio: 67, Iteración:81067, Exploración: 0.5099857462495653, Recompensa Acumulada: -21.0
# Episodio: 68, Iteración:82198, Exploración: 0.5048858887870696, Recompensa Acumulada: -20.0
# Episodio: 69, Iteración:83699, Exploración: 0.4998370298991989, Recompensa Acumulada: -20.0
# Episodio: 70, Iteración:84826, Exploración: 0.49483865960020695, Recompensa Acumulada: -21.0
# Episodio: 71, Iteración:86145, Exploración: 0.4898902730042049, Recompensa Acumulada: -20.0
# Episodio: 72, Iteración:87248, Exploración: 0.48499137027416284, Recompensa Acumulada: -21.0
# Episodio: 73, Iteración:88542, Exploración: 0.4801414565714212, Recompensa Acumulada: -20.0
# Episodio: 74, Iteración:89604, Exploración: 0.475340042005707, Recompensa Acumulada: -21.0
# Episodio: 75, Iteración:90926, Exploración: 0.47058664158564995, Recompensa Acumulada: -20.0
# Episodio: 76, Iteración:92046, Exploración: 0.4658807751697934, Recompensa Acumulada: -20.0
# Episodio: 77, Iteración:93220, Exploración: 0.4612219674180955, Recompensa Acumulada: -21.0
# Episodio: 78, Iteración:94615, Exploración: 0.45660974774391455, Recompensa Acumulada: -18.0
# Episodio: 79, Iteración:95865, Exploración: 0.4520436502664754, Recompensa Acumulada: -21.0
# Episodio: 80, Iteración:96877, Exploración: 0.44752321376381066, Recompensa Acumulada: -21.0
# Episodio: 81, Iteración:98033, Exploración: 0.44304798162617254, Recompensa Acumulada: -20.0
# Episodio: 82, Iteración:99081, Exploración: 0.4386175018099108, Recompensa Acumulada: -21.0
# Episodio: 83, Iteración:100280, Exploración: 0.4342313267918117, Recompensa Acumulada: -20.0
# Episodio: 84, Iteración:101492, Exploración: 0.4298890135238936, Recompensa Acumulada: -21.0
# Episodio: 85, Iteración:102718, Exploración: 0.42559012338865465, Recompensa Acumulada: -21.0
# Episodio: 86, Iteración:103742, Exploración: 0.4213342221547681, Recompensa Acumulada: -21.0
# Episodio: 87, Iteración:105030, Exploración: 0.41712087993322045, Recompensa Acumulada: -20.0
# Episodio: 88, Iteración:106170, Exploración: 0.41294967113388825, Recompensa Acumulada: -21.0
# Episodio: 89, Iteración:107472, Exploración: 0.40882017442254937, Recompensa Acumulada: -19.0
# Episodio: 90, Iteración:108731, Exploración: 0.4047319726783239, Recompensa Acumulada: -21.0
# Episodio: 91, Iteración:109895, Exploración: 0.40068465295154065, Recompensa Acumulada: -20.0
# Episodio: 92, Iteración:110900, Exploración: 0.39667780642202527, Recompensa Acumulada: -21.0
# Episodio: 93, Iteración:111955, Exploración: 0.392711028357805, Recompensa Acumulada: -21.0
# Episodio: 94, Iteración:112995, Exploración: 0.38878391807422696, Recompensa Acumulada: -21.0
# Episodio: 95, Iteración:114121, Exploración: 0.3848960788934847, Recompensa Acumulada: -21.0
# Episodio: 96, Iteración:115407, Exploración: 0.38104711810454983, Recompensa Acumulada: -19.0
# Episodio: 97, Iteración:116492, Exploración: 0.37723664692350434, Recompensa Acumulada: -21.0
# Episodio: 98, Iteración:117734, Exploración: 0.37346428045426927, Recompensa Acumulada: -20.0
# Episodio: 99, Iteración:118794, Exploración: 0.36972963764972655, Recompensa Acumulada: -21.0
# Episodio: 100, Iteración:120086, Exploración: 0.36603234127322926, Recompensa Acumulada: -19.0
# Episodio: 101, Iteración:121198, Exploración: 0.36237201786049694, Recompensa Acumulada: -20.0
# Episodio: 102, Iteración:122280, Exploración: 0.358748297681892, Recompensa Acumulada: -21.0
# Episodio: 103, Iteración:123672, Exploración: 0.35516081470507305, Recompensa Acumulada: -19.0
# Episodio: 104, Iteración:124940, Exploración: 0.3516092065580223, Recompensa Acumulada: -19.0
# Episodio: 105, Iteración:126000, Exploración: 0.34809311449244207, Recompensa Acumulada: -21.0
# Episodio: 106, Iteración:127125, Exploración: 0.34461218334751764, Recompensa Acumulada: -21.0
# Episodio: 107, Iteración:128179, Exploración: 0.34116606151404244, Recompensa Acumulada: -21.0
# Episodio: 108, Iteración:129277, Exploración: 0.337754400898902, Recompensa Acumulada: -21.0
# Episodio: 109, Iteración:130334, Exploración: 0.334376856889913, Recompensa Acumulada: -21.0
# Episodio: 110, Iteración:131387, Exploración: 0.33103308832101386, Recompensa Acumulada: -21.0
# Episodio: 111, Iteración:132450, Exploración: 0.3277227574378037, Recompensa Acumulada: -21.0
# Episodio: 112, Iteración:133575, Exploración: 0.3244455298634257, Recompensa Acumulada: -21.0
# Episodio: 113, Iteración:134634, Exploración: 0.3212010745647914, Recompensa Acumulada: -21.0
# Episodio: 114, Iteración:135724, Exploración: 0.3179890638191435, Recompensa Acumulada: -21.0
# Episodio: 115, Iteración:136791, Exploración: 0.31480917318095203, Recompensa Acumulada: -21.0
# Episodio: 116, Iteración:137919, Exploración: 0.3116610814491425, Recompensa Acumulada: -20.0
# Episodio: 117, Iteración:138974, Exploración: 0.30854447063465107, Recompensa Acumulada: -21.0
# Episodio: 118, Iteración:140020, Exploración: 0.30545902592830454, Recompensa Acumulada: -21.0
# Episodio: 119, Iteración:141114, Exploración: 0.3024044356690215, Recompensa Acumulada: -21.0
# Episodio: 120, Iteración:142174, Exploración: 0.29938039131233124, Recompensa Acumulada: -21.0
# Episodio: 121, Iteración:143282, Exploración: 0.2963865873992079, Recompensa Acumulada: -21.0
# Episodio: 122, Iteración:144399, Exploración: 0.29342272152521587, Recompensa Acumulada: -20.0
# Episodio: 123, Iteración:145504, Exploración: 0.2904884943099637, Recompensa Acumulada: -20.0
# Episodio: 124, Iteración:146631, Exploración: 0.28758360936686406, Recompensa Acumulada: -20.0
# Episodio: 125, Iteración:147837, Exploración: 0.2847077732731954, Recompensa Acumulada: -20.0
# Episodio: 126, Iteración:148956, Exploración: 0.28186069554046345, Recompensa Acumulada: -20.0
# Episodio: 127, Iteración:150059, Exploración: 0.2790420885850588, Recompensa Acumulada: -21.0
# Episodio: 128, Iteración:151189, Exploración: 0.2762516676992082, Recompensa Acumulada: -20.0
# Episodio: 129, Iteración:152313, Exploración: 0.27348915102221616, Recompensa Acumulada: -20.0
# Episodio: 130, Iteración:153366, Exploración: 0.270754259511994, Recompensa Acumulada: -21.0
# Episodio: 131, Iteración:154494, Exploración: 0.26804671691687404, Recompensa Acumulada: -20.0
# Episodio: 132, Iteración:155541, Exploración: 0.2653662497477053, Recompensa Acumulada: -21.0
# Episodio: 133, Iteración:156593, Exploración: 0.2627125872502282, Recompensa Acumulada: -21.0
# Episodio: 134, Iteración:157715, Exploración: 0.2600854613777259, Recompensa Acumulada: -20.0
# Episodio: 135, Iteración:158757, Exploración: 0.2574846067639487, Recompensa Acumulada: -21.0
# Episodio: 136, Iteración:159852, Exploración: 0.2549097606963092, Recompensa Acumulada: -21.0
# Episodio: 137, Iteración:160981, Exploración: 0.2523606630893461, Recompensa Acumulada: -21.0
# Episodio: 138, Iteración:162116, Exploración: 0.24983705645845267, Recompensa Acumulada: -20.0
# Episodio: 139, Iteración:163245, Exploración: 0.24733868589386815, Recompensa Acumulada: -20.0
# Episodio: 140, Iteración:164441, Exploración: 0.24486529903492946, Recompensa Acumulada: -20.0
# Episodio: 141, Iteración:165581, Exploración: 0.24241664604458016, Recompensa Acumulada: -20.0
# Episodio: 142, Iteración:166713, Exploración: 0.23999247958413436, Recompensa Acumulada: -20.0
# Episodio: 143, Iteración:167830, Exploración: 0.23759255478829303, Recompensa Acumulada: -20.0
# Episodio: 144, Iteración:168873, Exploración: 0.2352166292404101, Recompensa Acumulada: -21.0
# Episodio: 145, Iteración:169994, Exploración: 0.232864462948006, Recompensa Acumulada: -20.0
# Episodio: 146, Iteración:171123, Exploración: 0.23053581831852593, Recompensa Acumulada: -20.0
# Episodio: 147, Iteración:172255, Exploración: 0.22823046013534068, Recompensa Acumulada: -20.0
# Episodio: 148, Iteración:173419, Exploración: 0.22594815553398728, Recompensa Acumulada: -20.0
# Episodio: 149, Iteración:174586, Exploración: 0.22368867397864742, Recompensa Acumulada: -21.0
# Episodio: 150, Iteración:175706, Exploración: 0.22145178723886094, Recompensa Acumulada: -20.0
# Episodio: 151, Iteración:176754, Exploración: 0.21923726936647234, Recompensa Acumulada: -21.0
# Episodio: 152, Iteración:177897, Exploración: 0.2170448966728076, Recompensa Acumulada: -21.0
# Episodio: 153, Iteración:179018, Exploración: 0.21487444770607952, Recompensa Acumulada: -20.0
# Episodio: 154, Iteración:180075, Exploración: 0.21272570322901874, Recompensa Acumulada: -21.0
# Episodio: 155, Iteración:181200, Exploración: 0.21059844619672854, Recompensa Acumulada: -20.0
# Episodio: 156, Iteración:182332, Exploración: 0.20849246173476127, Recompensa Acumulada: -21.0
# Episodio: 157, Iteración:183378, Exploración: 0.20640753711741366, Recompensa Acumulada: -21.0
# Episodio: 158, Iteración:184503, Exploración: 0.20434346174623952, Recompensa Acumulada: -20.0
# Episodio: 159, Iteración:185540, Exploración: 0.20230002712877712, Recompensa Acumulada: -21.0
# Episodio: 160, Iteración:186777, Exploración: 0.20027702685748935, Recompensa Acumulada: -19.0
# Episodio: 161, Iteración:187881, Exploración: 0.19827425658891445, Recompensa Acumulada: -21.0
# Episodio: 162, Iteración:188978, Exploración: 0.1962915140230253, Recompensa Acumulada: -21.0
# Episodio: 163, Iteración:190338, Exploración: 0.19432859888279505, Recompensa Acumulada: -19.0
# Episodio: 164, Iteración:191462, Exploración: 0.1923853128939671, Recompensa Acumulada: -20.0
# Episodio: 165, Iteración:192590, Exploración: 0.19046145976502743, Recompensa Acumulada: -20.0
# Episodio: 166, Iteración:193711, Exploración: 0.18855684516737714, Recompensa Acumulada: -20.0
# Episodio: 167, Iteración:194830, Exploración: 0.18667127671570335, Recompensa Acumulada: -20.0
# Episodio: 168, Iteración:195916, Exploración: 0.18480456394854633, Recompensa Acumulada: -21.0
# Episodio: 169, Iteración:197056, Exploración: 0.18295651830906087, Recompensa Acumulada: -21.0
# Episodio: 170, Iteración:198262, Exploración: 0.18112695312597027, Recompensa Acumulada: -20.0
# Episodio: 171, Iteración:199285, Exploración: 0.17931568359471056, Recompensa Acumulada: -21.0
# Episodio: 172, Iteración:200517, Exploración: 0.17752252675876345, Recompensa Acumulada: -19.0
# Episodio: 173, Iteración:201678, Exploración: 0.17574730149117582, Recompensa Acumulada: -20.0
# Episodio: 174, Iteración:202735, Exploración: 0.17398982847626407, Recompensa Acumulada: -21.0
# Episodio: 175, Iteración:203799, Exploración: 0.17224993019150142, Recompensa Acumulada: -21.0
# Episodio: 176, Iteración:204857, Exploración: 0.1705274308895864, Recompensa Acumulada: -21.0
# Episodio: 177, Iteración:205967, Exploración: 0.16882215658069055, Recompensa Acumulada: -20.0
# Episodio: 178, Iteración:207035, Exploración: 0.16713393501488363, Recompensa Acumulada: -21.0
# Episodio: 179, Iteración:208165, Exploración: 0.16546259566473479, Recompensa Acumulada: -20.0
# Episodio: 180, Iteración:209282, Exploración: 0.16380796970808745, Recompensa Acumulada: -20.0
# Episodio: 181, Iteración:210328, Exploración: 0.16216989001100657, Recompensa Acumulada: -21.0
# Episodio: 182, Iteración:211499, Exploración: 0.1605481911108965, Recompensa Acumulada: -20.0
# Episodio: 183, Iteración:212620, Exploración: 0.15894270919978754, Recompensa Acumulada: -20.0
# Episodio: 184, Iteración:213820, Exploración: 0.15735328210778965, Recompensa Acumulada: -20.0
# Episodio: 185, Iteración:214937, Exploración: 0.15577974928671176, Recompensa Acumulada: -20.0
# Episodio: 186, Iteración:216057, Exploración: 0.15422195179384465, Recompensa Acumulada: -20.0
# Episodio: 187, Iteración:217178, Exploración: 0.1526797322759062, Recompensa Acumulada: -20.0
# Episodio: 188, Iteración:218210, Exploración: 0.15115293495314713, Recompensa Acumulada: -21.0
