# %%
import random
import gym
import numpy as np
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import sklearn.preprocessing
from lib import plotting

ENV_NAME = "CartPole-v1"
env = gym.make(ENV_NAME)
# Out:
# Using TensorFlow backend.

# %%
class Estimator():
    """
    Red Neuronal que aproxima la función de valor estado acción (q-function)
    """   
    def __init__(self, dimS, nA, learning_rate=0.001):

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(dimS,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(nA, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=learning_rate))
     
    def update(self, states, q_values, verbose=0):
        """
        Realiza un update de los parámetros de la red neuronal usando un batch de estados y batch de vectores de valores
        de la función estado-acción correspondientes
        """
        self.model.fit(states, q_values, verbose=0)
    
    def predict(self, s):
        """
        Realiza una predicción de la función de valor estado-accion dado el estado
        
        Argumentos:
            s: estado para el cual realizar la predicción
            
        Retorna:
            Un vector con la predicción de la función de valor para todas las accións
        """
        return self.model.predict(s)

# %%
class Learner:
    def __init__(self, env, estimator, num_episodes, discount_factor=1.0, 
                 exploration_max=1.0, exploration_min=0.01, epsilon_decay=0.99, memory_size=1000000, 
                 batch_size=20, run_online=False, use_qlearning=True):
        """
        Algoritmo q-learning/sarsa con experience replay utilizando aproximación de funciones.

        Argumentos de inicialización:
            env: ambiente de OpenAI.
            estimator: función de aproximación de la función de valor estado-acción.
            num_episodes: número de episodios durante los cuales entrenar el estimador.
            discount_factor: factor de descuento gama.
            exploration_max: probabilidad de tomar una acción aleatoria inicial.
            exploration_min: mínima probabilidad de tomar una acción aleatoria.
            epsilon_decay: en cada episodio la probabilidad de una acción aleatoria deace por este factor.
        """
        self.exploration_rate = exploration_max
        self.exploration_min = exploration_min
        self.env = env
        self.estimator = estimator
        self.num_episodes = num_episodes
        self.discount_factor = discount_factor
        self.epsilon_decay = epsilon_decay
        self.memory = deque(maxlen=memory_size)
        self.batch_size = batch_size
        self.run_online = run_online
        self.use_qlearning = use_qlearning
        
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        
    def decay_exploration_rate(self):
        self.exploration_rate *= self.epsilon_decay
        self.exploration_rate = max(self.exploration_min, self.exploration_rate)
        
    def policy_fn(self, state, epsilon):
        """
        Política epsilon-greedy basada en la función de aproximación actual y la probabilidad de exploración epsilon.

        Retorna:
            Un vector con la probabilidad de tomar cada acción.
        """
        A = np.ones(env.action_space.n, dtype=float) * self.exploration_rate / env.action_space.n
        q_values = self.estimator.predict(state)
        best_action = np.argmax(q_values[0])
        A[best_action] += (1.0 - epsilon)
        return A
    
    def experience_replay(self):
        """
        Realiza una corrida de entrenamiento de la función de aproximación dado un batch de experiencia acumulada.
        """
        if len(self.memory) < self.batch_size:
            return
        
        batch = random.sample(self.memory, self.batch_size)
        
        batch_q_values = np.zeros((self.batch_size, self.env.action_space.n))
        batch_states = np.zeros((self.batch_size, self.env.observation_space.shape[0]))
        
        for i_batch, (state, action, reward, next_state, terminal) in enumerate(batch):
            
            q_update = reward
            if not terminal:
                ## q-learning:
                if self.use_qlearning:
                    q_update = reward + self.discount_factor * np.amax(self.estimator.predict(next_state)[0])
                else: 
                ## sarsa:
                    next_action_probs = self.policy_fn(next_state, self.exploration_rate)
                    next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)  
                    q_values_next = self.estimator.predict(next_state)[0]
                    q_update = reward + self.discount_factor * q_values_next[next_action]
            
            q_values = self.estimator.predict(state)
            q_values[0][action] = q_update
            batch_q_values[i_batch] = q_values
            batch_states[i_batch] = state
            i_batch += 1
    
        self.estimator.update(batch_states, batch_q_values, verbose=0)
        
    def train(self):    
        """
        Realiza Q-Learning o Sarsa con aproximación de la función de valor estado-acción.
        Retorna:
            Un objeto de tipo EpisodeStats con dos arrays de numpy para la longitud y recompensa acumulada de cada
            episodio respectivamente.
        """
        stats = plotting.EpisodeStats(
            episode_lengths=np.zeros(self.num_episodes),
            episode_rewards=np.zeros(self.num_episodes))    
        
        for run in range(self.num_episodes):
            state = env.reset()
            state = np.reshape(state, [1, self.env.observation_space.shape[0]])
            step = 0
            cum_reward = 0.0
            
            action = np.random.choice(self.env.action_space.n, p=self.policy_fn(state, self.exploration_rate))
            
            while True:
                env.render()
                
                next_state, reward, terminal, info = env.step(action)
                
                reward = reward if not terminal else -reward
                cum_reward += reward*self.discount_factor**step
                
                next_state = np.reshape(next_state, [1, self.env.observation_space.shape[0]])
                
                if not terminal:
                    next_action = np.random.choice(self.env.action_space.n, p=self.policy_fn(next_state, self.exploration_rate))
                else:
                    next_action = None
                
                
                self.remember(state, action, reward, next_state, terminal)
                
                if self.run_online:
                    q_update = reward
                    if not terminal:
                        ## q-learning:
                        if self.use_qlearning:
                            q_update = reward + self.discount_factor * np.amax(self.estimator.predict(next_state)[0])
                        else: 
                        ## sarsa:
                            next_action_probs = self.policy_fn(next_state, self.exploration_rate)
                            next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)  
                            q_values_next = self.estimator.predict(next_state)[0]
                            q_update = reward + self.discount_factor * q_values_next[next_action]

                    q_values = self.estimator.predict(state)
                    q_values[0][action] = q_update
                    self.estimator.update([state], [q_values], verbose=0)
                    
                
                state = next_state
                action = next_action
                
                step += 1
                if terminal:
                    print("Episodio: " + str(run) + ", Exploración: " + str(self.exploration_rate) + 
                          ", Recompensa Acumulada: " + str(cum_reward))
                    # Actualizar estadísticas
                    stats.episode_rewards[run] = cum_reward
                    stats.episode_lengths[run] = step
                    break        
                    
                if not self.run_online:
                    self.experience_replay()
            self.decay_exploration_rate()
        return stats

# %%
estimator = Estimator(env.observation_space.shape[0], env.action_space.n)
learner = Learner(env, estimator, 500, run_online=True, use_qlearning=False)

# %%
stats = learner.train()
# Out:
# Episodio: 0, Exploración: 1.0, Recompensa Acumulada: 37.0
# Episodio: 1, Exploración: 0.99, Recompensa Acumulada: 21.0
# Episodio: 2, Exploración: 0.9801, Recompensa Acumulada: 21.0
# Episodio: 3, Exploración: 0.9702989999999999, Recompensa Acumulada: 15.0
# Episodio: 4, Exploración: 0.96059601, Recompensa Acumulada: 15.0
# Episodio: 5, Exploración: 0.9509900498999999, Recompensa Acumulada: 51.0
# Episodio: 6, Exploración: 0.9414801494009999, Recompensa Acumulada: 26.0
# Episodio: 7, Exploración: 0.9320653479069899, Recompensa Acumulada: 15.0
# Episodio: 8, Exploración: 0.92274469442792, Recompensa Acumulada: 20.0
# Episodio: 9, Exploración: 0.9135172474836407, Recompensa Acumulada: 13.0
# Episodio: 10, Exploración: 0.9043820750088043, Recompensa Acumulada: 26.0
# Episodio: 11, Exploración: 0.8953382542587163, Recompensa Acumulada: 35.0
# Episodio: 12, Exploración: 0.8863848717161291, Recompensa Acumulada: 18.0
# Episodio: 13, Exploración: 0.8775210229989678, Recompensa Acumulada: 20.0
# Episodio: 14, Exploración: 0.8687458127689781, Recompensa Acumulada: 53.0
# Episodio: 15, Exploración: 0.8600583546412883, Recompensa Acumulada: 12.0
# Episodio: 16, Exploración: 0.8514577710948754, Recompensa Acumulada: 19.0
# Episodio: 17, Exploración: 0.8429431933839266, Recompensa Acumulada: 16.0
# Episodio: 18, Exploración: 0.8345137614500874, Recompensa Acumulada: 8.0
# Episodio: 19, Exploración: 0.8261686238355865, Recompensa Acumulada: 7.0
# Episodio: 20, Exploración: 0.8179069375972307, Recompensa Acumulada: 14.0
# Episodio: 21, Exploración: 0.8097278682212583, Recompensa Acumulada: 18.0
# Episodio: 22, Exploración: 0.8016305895390458, Recompensa Acumulada: 21.0
# Episodio: 23, Exploración: 0.7936142836436553, Recompensa Acumulada: 10.0
# Episodio: 24, Exploración: 0.7856781408072188, Recompensa Acumulada: 8.0
# Episodio: 25, Exploración: 0.7778213593991465, Recompensa Acumulada: 17.0
# Episodio: 26, Exploración: 0.7700431458051551, Recompensa Acumulada: 11.0
# Episodio: 27, Exploración: 0.7623427143471035, Recompensa Acumulada: 8.0
# Episodio: 28, Exploración: 0.7547192872036325, Recompensa Acumulada: 14.0
# Episodio: 29, Exploración: 0.7471720943315961, Recompensa Acumulada: 9.0
# Episodio: 30, Exploración: 0.7397003733882802, Recompensa Acumulada: 25.0
# Episodio: 31, Exploración: 0.7323033696543974, Recompensa Acumulada: 20.0
# Episodio: 32, Exploración: 0.7249803359578534, Recompensa Acumulada: 24.0
# Episodio: 33, Exploración: 0.7177305325982748, Recompensa Acumulada: 12.0
# Episodio: 34, Exploración: 0.7105532272722921, Recompensa Acumulada: 14.0
# Episodio: 35, Exploración: 0.7034476949995692, Recompensa Acumulada: 19.0
# Episodio: 36, Exploración: 0.6964132180495735, Recompensa Acumulada: 19.0
# Episodio: 37, Exploración: 0.6894490858690777, Recompensa Acumulada: 16.0
# Episodio: 38, Exploración: 0.682554595010387, Recompensa Acumulada: 24.0
# Episodio: 39, Exploración: 0.6757290490602831, Recompensa Acumulada: 9.0
# Episodio: 40, Exploración: 0.6689717585696803, Recompensa Acumulada: 8.0
# Episodio: 41, Exploración: 0.6622820409839835, Recompensa Acumulada: 10.0
# Episodio: 42, Exploración: 0.6556592205741436, Recompensa Acumulada: 9.0
# Episodio: 43, Exploración: 0.6491026283684022, Recompensa Acumulada: 25.0
# Episodio: 44, Exploración: 0.6426116020847181, Recompensa Acumulada: 6.0
# Episodio: 45, Exploración: 0.6361854860638709, Recompensa Acumulada: 15.0
# Episodio: 46, Exploración: 0.6298236312032323, Recompensa Acumulada: 9.0
# Episodio: 47, Exploración: 0.6235253948912, Recompensa Acumulada: 17.0
# Episodio: 48, Exploración: 0.617290140942288, Recompensa Acumulada: 34.0
# Episodio: 49, Exploración: 0.6111172395328651, Recompensa Acumulada: 11.0
# Episodio: 50, Exploración: 0.6050060671375365, Recompensa Acumulada: 12.0
# Episodio: 51, Exploración: 0.5989560064661611, Recompensa Acumulada: 15.0
# Episodio: 52, Exploración: 0.5929664464014994, Recompensa Acumulada: 17.0
# Episodio: 53, Exploración: 0.5870367819374844, Recompensa Acumulada: 19.0
# Episodio: 54, Exploración: 0.5811664141181095, Recompensa Acumulada: 14.0
# Episodio: 55, Exploración: 0.5753547499769285, Recompensa Acumulada: 55.0
# Episodio: 56, Exploración: 0.5696012024771592, Recompensa Acumulada: 8.0
# Episodio: 57, Exploración: 0.5639051904523876, Recompensa Acumulada: 12.0
# Episodio: 58, Exploración: 0.5582661385478638, Recompensa Acumulada: 10.0
# Episodio: 59, Exploración: 0.5526834771623851, Recompensa Acumulada: 9.0
# Episodio: 60, Exploración: 0.5471566423907612, Recompensa Acumulada: 8.0
# Episodio: 61, Exploración: 0.5416850759668536, Recompensa Acumulada: 11.0
# Episodio: 62, Exploración: 0.536268225207185, Recompensa Acumulada: 19.0
# Episodio: 63, Exploración: 0.5309055429551132, Recompensa Acumulada: 10.0
# Episodio: 64, Exploración: 0.525596487525562, Recompensa Acumulada: 12.0
# Episodio: 65, Exploración: 0.5203405226503064, Recompensa Acumulada: 10.0
# Episodio: 66, Exploración: 0.5151371174238033, Recompensa Acumulada: 17.0
# Episodio: 67, Exploración: 0.5099857462495653, Recompensa Acumulada: 27.0
# Episodio: 68, Exploración: 0.5048858887870696, Recompensa Acumulada: 16.0
# Episodio: 69, Exploración: 0.4998370298991989, Recompensa Acumulada: 8.0
# Episodio: 70, Exploración: 0.49483865960020695, Recompensa Acumulada: 11.0
# Episodio: 71, Exploración: 0.4898902730042049, Recompensa Acumulada: 26.0
# Episodio: 72, Exploración: 0.48499137027416284, Recompensa Acumulada: 8.0
# Episodio: 73, Exploración: 0.4801414565714212, Recompensa Acumulada: 11.0
# Episodio: 74, Exploración: 0.475340042005707, Recompensa Acumulada: 8.0
# Episodio: 75, Exploración: 0.47058664158564995, Recompensa Acumulada: 7.0
# Episodio: 76, Exploración: 0.4658807751697934, Recompensa Acumulada: 11.0
# Episodio: 77, Exploración: 0.4612219674180955, Recompensa Acumulada: 12.0
# Episodio: 78, Exploración: 0.45660974774391455, Recompensa Acumulada: 10.0
# Episodio: 79, Exploración: 0.4520436502664754, Recompensa Acumulada: 9.0
# Episodio: 80, Exploración: 0.44752321376381066, Recompensa Acumulada: 19.0
# Episodio: 81, Exploración: 0.44304798162617254, Recompensa Acumulada: 28.0
# Episodio: 82, Exploración: 0.4386175018099108, Recompensa Acumulada: 17.0
# Episodio: 83, Exploración: 0.4342313267918117, Recompensa Acumulada: 15.0
# Episodio: 84, Exploración: 0.4298890135238936, Recompensa Acumulada: 9.0
# Episodio: 85, Exploración: 0.42559012338865465, Recompensa Acumulada: 10.0
# Episodio: 86, Exploración: 0.4213342221547681, Recompensa Acumulada: 17.0
# Episodio: 87, Exploración: 0.41712087993322045, Recompensa Acumulada: 8.0
# Episodio: 88, Exploración: 0.41294967113388825, Recompensa Acumulada: 15.0
# Episodio: 89, Exploración: 0.40882017442254937, Recompensa Acumulada: 9.0
# Episodio: 90, Exploración: 0.4047319726783239, Recompensa Acumulada: 8.0
# Episodio: 91, Exploración: 0.40068465295154065, Recompensa Acumulada: 11.0
# Episodio: 92, Exploración: 0.39667780642202527, Recompensa Acumulada: 9.0
# Episodio: 93, Exploración: 0.392711028357805, Recompensa Acumulada: 9.0
# Episodio: 94, Exploración: 0.38878391807422696, Recompensa Acumulada: 8.0
# Episodio: 95, Exploración: 0.3848960788934847, Recompensa Acumulada: 11.0
# Episodio: 96, Exploración: 0.38104711810454983, Recompensa Acumulada: 9.0
# Episodio: 97, Exploración: 0.37723664692350434, Recompensa Acumulada: 13.0
# Episodio: 98, Exploración: 0.37346428045426927, Recompensa Acumulada: 14.0
# Episodio: 99, Exploración: 0.36972963764972655, Recompensa Acumulada: 13.0
# Episodio: 100, Exploración: 0.36603234127322926, Recompensa Acumulada: 22.0
# Episodio: 101, Exploración: 0.36237201786049694, Recompensa Acumulada: 33.0
# Episodio: 102, Exploración: 0.358748297681892, Recompensa Acumulada: 17.0
# Episodio: 103, Exploración: 0.35516081470507305, Recompensa Acumulada: 35.0
# Episodio: 104, Exploración: 0.3516092065580223, Recompensa Acumulada: 42.0
# Episodio: 105, Exploración: 0.34809311449244207, Recompensa Acumulada: 61.0
# Episodio: 106, Exploración: 0.34461218334751764, Recompensa Acumulada: 135.0
# Episodio: 107, Exploración: 0.34116606151404244, Recompensa Acumulada: 12.0
# Episodio: 108, Exploración: 0.337754400898902, Recompensa Acumulada: 119.0
# Episodio: 109, Exploración: 0.334376856889913, Recompensa Acumulada: 35.0
# Episodio: 110, Exploración: 0.33103308832101386, Recompensa Acumulada: 44.0
# Episodio: 111, Exploración: 0.3277227574378037, Recompensa Acumulada: 10.0
# Episodio: 112, Exploración: 0.3244455298634257, Recompensa Acumulada: 13.0
# Episodio: 113, Exploración: 0.3212010745647914, Recompensa Acumulada: 9.0
# Episodio: 114, Exploración: 0.3179890638191435, Recompensa Acumulada: 10.0
# Episodio: 115, Exploración: 0.31480917318095203, Recompensa Acumulada: 9.0
# Episodio: 116, Exploración: 0.3116610814491425, Recompensa Acumulada: 8.0
# Episodio: 117, Exploración: 0.30854447063465107, Recompensa Acumulada: 6.0
# Episodio: 118, Exploración: 0.30545902592830454, Recompensa Acumulada: 14.0
# Episodio: 119, Exploración: 0.3024044356690215, Recompensa Acumulada: 30.0
# Episodio: 120, Exploración: 0.29938039131233124, Recompensa Acumulada: 19.0
# Episodio: 121, Exploración: 0.2963865873992079, Recompensa Acumulada: 15.0
# Episodio: 122, Exploración: 0.29342272152521587, Recompensa Acumulada: 20.0
# Episodio: 123, Exploración: 0.2904884943099637, Recompensa Acumulada: 12.0
# Episodio: 124, Exploración: 0.28758360936686406, Recompensa Acumulada: 17.0
# Episodio: 125, Exploración: 0.2847077732731954, Recompensa Acumulada: 12.0
# Episodio: 126, Exploración: 0.28186069554046345, Recompensa Acumulada: 12.0
# Episodio: 127, Exploración: 0.2790420885850588, Recompensa Acumulada: 8.0
# Episodio: 128, Exploración: 0.2762516676992082, Recompensa Acumulada: 9.0
# Episodio: 129, Exploración: 0.27348915102221616, Recompensa Acumulada: 10.0
# Episodio: 130, Exploración: 0.270754259511994, Recompensa Acumulada: 9.0
# Episodio: 131, Exploración: 0.26804671691687404, Recompensa Acumulada: 8.0
# Episodio: 132, Exploración: 0.2653662497477053, Recompensa Acumulada: 9.0
# Episodio: 133, Exploración: 0.2627125872502282, Recompensa Acumulada: 13.0
# Episodio: 134, Exploración: 0.2600854613777259, Recompensa Acumulada: 17.0
# Episodio: 135, Exploración: 0.2574846067639487, Recompensa Acumulada: 35.0
# Episodio: 136, Exploración: 0.2549097606963092, Recompensa Acumulada: 40.0
# Episodio: 137, Exploración: 0.2523606630893461, Recompensa Acumulada: 18.0
# Episodio: 138, Exploración: 0.24983705645845267, Recompensa Acumulada: 20.0
# Episodio: 139, Exploración: 0.24733868589386815, Recompensa Acumulada: 17.0
# Episodio: 140, Exploración: 0.24486529903492946, Recompensa Acumulada: 20.0
# Episodio: 141, Exploración: 0.24241664604458016, Recompensa Acumulada: 17.0
# Episodio: 142, Exploración: 0.23999247958413436, Recompensa Acumulada: 15.0
# Episodio: 143, Exploración: 0.23759255478829303, Recompensa Acumulada: 26.0
# Episodio: 144, Exploración: 0.2352166292404101, Recompensa Acumulada: 17.0
# Episodio: 145, Exploración: 0.232864462948006, Recompensa Acumulada: 12.0
# Episodio: 146, Exploración: 0.23053581831852593, Recompensa Acumulada: 16.0
# Episodio: 147, Exploración: 0.22823046013534068, Recompensa Acumulada: 16.0
# Episodio: 148, Exploración: 0.22594815553398728, Recompensa Acumulada: 21.0
# Episodio: 149, Exploración: 0.22368867397864742, Recompensa Acumulada: 17.0
# Episodio: 150, Exploración: 0.22145178723886094, Recompensa Acumulada: 21.0
# Episodio: 151, Exploración: 0.21923726936647234, Recompensa Acumulada: 40.0
# Episodio: 152, Exploración: 0.2170448966728076, Recompensa Acumulada: 71.0
# Episodio: 153, Exploración: 0.21487444770607952, Recompensa Acumulada: 58.0
# Episodio: 154, Exploración: 0.21272570322901874, Recompensa Acumulada: 77.0
# Episodio: 155, Exploración: 0.21059844619672854, Recompensa Acumulada: 35.0
# Episodio: 156, Exploración: 0.20849246173476127, Recompensa Acumulada: 26.0
# Episodio: 157, Exploración: 0.20640753711741366, Recompensa Acumulada: 11.0
# Episodio: 158, Exploración: 0.20434346174623952, Recompensa Acumulada: 8.0
# Episodio: 159, Exploración: 0.20230002712877712, Recompensa Acumulada: 11.0
# Episodio: 160, Exploración: 0.20027702685748935, Recompensa Acumulada: 8.0
# Episodio: 161, Exploración: 0.19827425658891445, Recompensa Acumulada: 10.0
# Episodio: 162, Exploración: 0.1962915140230253, Recompensa Acumulada: 12.0
# Episodio: 163, Exploración: 0.19432859888279505, Recompensa Acumulada: 13.0
# Episodio: 164, Exploración: 0.1923853128939671, Recompensa Acumulada: 65.0
# Episodio: 165, Exploración: 0.19046145976502743, Recompensa Acumulada: 26.0
# Episodio: 166, Exploración: 0.18855684516737714, Recompensa Acumulada: 18.0
# Episodio: 167, Exploración: 0.18667127671570335, Recompensa Acumulada: 14.0
# Episodio: 168, Exploración: 0.18480456394854633, Recompensa Acumulada: 13.0
# Episodio: 169, Exploración: 0.18295651830906087, Recompensa Acumulada: 7.0
# Episodio: 170, Exploración: 0.18112695312597027, Recompensa Acumulada: 9.0
# Episodio: 171, Exploración: 0.17931568359471056, Recompensa Acumulada: 6.0
# Episodio: 172, Exploración: 0.17752252675876345, Recompensa Acumulada: 12.0
# Episodio: 173, Exploración: 0.17574730149117582, Recompensa Acumulada: 7.0
# Episodio: 174, Exploración: 0.17398982847626407, Recompensa Acumulada: 8.0
# Episodio: 175, Exploración: 0.17224993019150142, Recompensa Acumulada: 10.0
# Episodio: 176, Exploración: 0.1705274308895864, Recompensa Acumulada: 7.0
# Episodio: 177, Exploración: 0.16882215658069055, Recompensa Acumulada: 7.0
# Episodio: 178, Exploración: 0.16713393501488363, Recompensa Acumulada: 8.0
# Episodio: 179, Exploración: 0.16546259566473479, Recompensa Acumulada: 10.0
# Episodio: 180, Exploración: 0.16380796970808745, Recompensa Acumulada: 13.0
# Episodio: 181, Exploración: 0.16216989001100657, Recompensa Acumulada: 9.0
# Episodio: 182, Exploración: 0.1605481911108965, Recompensa Acumulada: 12.0
# Episodio: 183, Exploración: 0.15894270919978754, Recompensa Acumulada: 8.0
# Episodio: 184, Exploración: 0.15735328210778965, Recompensa Acumulada: 9.0
# Episodio: 185, Exploración: 0.15577974928671176, Recompensa Acumulada: 14.0
# Episodio: 186, Exploración: 0.15422195179384465, Recompensa Acumulada: 16.0
# Episodio: 187, Exploración: 0.1526797322759062, Recompensa Acumulada: 116.0
# Episodio: 188, Exploración: 0.15115293495314713, Recompensa Acumulada: 20.0
# Episodio: 189, Exploración: 0.14964140560361566, Recompensa Acumulada: 14.0
# Episodio: 190, Exploración: 0.1481449915475795, Recompensa Acumulada: 11.0
# Episodio: 191, Exploración: 0.1466635416321037, Recompensa Acumulada: 14.0
# Episodio: 192, Exploración: 0.14519690621578268, Recompensa Acumulada: 10.0
# Episodio: 193, Exploración: 0.14374493715362485, Recompensa Acumulada: 10.0
# Episodio: 194, Exploración: 0.1423074877820886, Recompensa Acumulada: 12.0
# Episodio: 195, Exploración: 0.1408844129042677, Recompensa Acumulada: 8.0
# Episodio: 196, Exploración: 0.13947556877522502, Recompensa Acumulada: 8.0
# Episodio: 197, Exploración: 0.13808081308747278, Recompensa Acumulada: 10.0
# Episodio: 198, Exploración: 0.13670000495659804, Recompensa Acumulada: 9.0
# Episodio: 199, Exploración: 0.13533300490703207, Recompensa Acumulada: 8.0
# Episodio: 200, Exploración: 0.13397967485796175, Recompensa Acumulada: 11.0
# Episodio: 201, Exploración: 0.13263987810938213, Recompensa Acumulada: 18.0
# Episodio: 202, Exploración: 0.1313134793282883, Recompensa Acumulada: 22.0
# Episodio: 203, Exploración: 0.13000034453500542, Recompensa Acumulada: 25.0
# Episodio: 204, Exploración: 0.12870034108965536, Recompensa Acumulada: 55.0
# Episodio: 205, Exploración: 0.12741333767875881, Recompensa Acumulada: 45.0
# Episodio: 206, Exploración: 0.12613920430197123, Recompensa Acumulada: 53.0
# Episodio: 207, Exploración: 0.12487781225895152, Recompensa Acumulada: 43.0
# Episodio: 208, Exploración: 0.123629034136362, Recompensa Acumulada: 65.0
# Episodio: 209, Exploración: 0.12239274379499838, Recompensa Acumulada: 88.0
# Episodio: 210, Exploración: 0.1211688163570484, Recompensa Acumulada: 27.0
# Episodio: 211, Exploración: 0.11995712819347792, Recompensa Acumulada: 20.0
# Episodio: 212, Exploración: 0.11875755691154315, Recompensa Acumulada: 12.0
# Episodio: 213, Exploración: 0.11756998134242772, Recompensa Acumulada: 27.0
# Episodio: 214, Exploración: 0.11639428152900344, Recompensa Acumulada: 60.0
# Episodio: 215, Exploración: 0.11523033871371341, Recompensa Acumulada: 41.0
# Episodio: 216, Exploración: 0.11407803532657627, Recompensa Acumulada: 20.0
# Episodio: 217, Exploración: 0.11293725497331052, Recompensa Acumulada: 17.0
# Episodio: 218, Exploración: 0.1118078824235774, Recompensa Acumulada: 11.0
# Episodio: 219, Exploración: 0.11068980359934164, Recompensa Acumulada: 14.0
# Episodio: 220, Exploración: 0.10958290556334822, Recompensa Acumulada: 10.0
# Episodio: 221, Exploración: 0.10848707650771475, Recompensa Acumulada: 13.0
# Episodio: 222, Exploración: 0.1074022057426376, Recompensa Acumulada: 8.0
# Episodio: 223, Exploración: 0.10632818368521123, Recompensa Acumulada: 13.0
# Episodio: 224, Exploración: 0.10526490184835911, Recompensa Acumulada: 32.0
# Episodio: 225, Exploración: 0.10421225282987552, Recompensa Acumulada: 104.0
# Episodio: 226, Exploración: 0.10317013030157676, Recompensa Acumulada: 17.0
# Episodio: 227, Exploración: 0.10213842899856099, Recompensa Acumulada: 55.0
# Episodio: 228, Exploración: 0.10111704470857538, Recompensa Acumulada: 57.0
# Episodio: 229, Exploración: 0.10010587426148963, Recompensa Acumulada: 28.0
# Episodio: 230, Exploración: 0.09910481551887473, Recompensa Acumulada: 123.0
# Episodio: 231, Exploración: 0.09811376736368599, Recompensa Acumulada: 67.0
# Episodio: 232, Exploración: 0.09713262969004913, Recompensa Acumulada: 51.0
# Episodio: 233, Exploración: 0.09616130339314863, Recompensa Acumulada: 48.0
# Episodio: 234, Exploración: 0.09519969035921715, Recompensa Acumulada: 37.0
# Episodio: 235, Exploración: 0.09424769345562498, Recompensa Acumulada: 30.0
# Episodio: 236, Exploración: 0.09330521652106873, Recompensa Acumulada: 17.0
# Episodio: 237, Exploración: 0.09237216435585804, Recompensa Acumulada: 15.0
# Episodio: 238, Exploración: 0.09144844271229946, Recompensa Acumulada: 49.0
# Episodio: 239, Exploración: 0.09053395828517646, Recompensa Acumulada: 61.0
# Episodio: 240, Exploración: 0.08962861870232469, Recompensa Acumulada: 37.0
# Episodio: 241, Exploración: 0.08873233251530144, Recompensa Acumulada: 32.0
# Episodio: 242, Exploración: 0.08784500919014843, Recompensa Acumulada: 74.0
# Episodio: 243, Exploración: 0.08696655909824694, Recompensa Acumulada: 49.0
# Episodio: 244, Exploración: 0.08609689350726446, Recompensa Acumulada: 18.0
# Episodio: 245, Exploración: 0.08523592457219181, Recompensa Acumulada: 14.0
# Episodio: 246, Exploración: 0.0843835653264699, Recompensa Acumulada: 39.0
# Episodio: 247, Exploración: 0.0835397296732052, Recompensa Acumulada: 98.0
# Episodio: 248, Exploración: 0.08270433237647315, Recompensa Acumulada: 59.0
# Episodio: 249, Exploración: 0.08187728905270841, Recompensa Acumulada: 49.0
# Episodio: 250, Exploración: 0.08105851616218133, Recompensa Acumulada: 50.0
# Episodio: 251, Exploración: 0.08024793100055952, Recompensa Acumulada: 56.0
# Episodio: 252, Exploración: 0.07944545169055392, Recompensa Acumulada: 53.0
# Episodio: 253, Exploración: 0.07865099717364837, Recompensa Acumulada: 18.0
# Episodio: 254, Exploración: 0.07786448720191189, Recompensa Acumulada: 13.0
# Episodio: 255, Exploración: 0.07708584232989277, Recompensa Acumulada: 18.0
# Episodio: 256, Exploración: 0.07631498390659384, Recompensa Acumulada: 21.0
# Episodio: 257, Exploración: 0.07555183406752791, Recompensa Acumulada: 170.0
# Episodio: 258, Exploración: 0.07479631572685264, Recompensa Acumulada: 10.0
# Episodio: 259, Exploración: 0.07404835256958411, Recompensa Acumulada: 10.0
# Episodio: 260, Exploración: 0.07330786904388827, Recompensa Acumulada: 13.0
# Episodio: 261, Exploración: 0.07257479035344938, Recompensa Acumulada: 11.0
# Episodio: 262, Exploración: 0.07184904244991488, Recompensa Acumulada: 12.0
# Episodio: 263, Exploración: 0.07113055202541574, Recompensa Acumulada: 10.0
# Episodio: 264, Exploración: 0.07041924650516158, Recompensa Acumulada: 15.0
# Episodio: 265, Exploración: 0.06971505404010997, Recompensa Acumulada: 17.0
# Episodio: 266, Exploración: 0.06901790349970886, Recompensa Acumulada: 46.0
# Episodio: 267, Exploración: 0.06832772446471178, Recompensa Acumulada: 24.0
# Episodio: 268, Exploración: 0.06764444722006466, Recompensa Acumulada: 15.0
# Episodio: 269, Exploración: 0.066968002747864, Recompensa Acumulada: 10.0
# Episodio: 270, Exploración: 0.06629832272038537, Recompensa Acumulada: 10.0
# Episodio: 271, Exploración: 0.06563533949318151, Recompensa Acumulada: 10.0
# Episodio: 272, Exploración: 0.06497898609824969, Recompensa Acumulada: 13.0
# Episodio: 273, Exploración: 0.0643291962372672, Recompensa Acumulada: 9.0
# Episodio: 274, Exploración: 0.06368590427489453, Recompensa Acumulada: 9.0
# Episodio: 275, Exploración: 0.06304904523214558, Recompensa Acumulada: 13.0
# Episodio: 276, Exploración: 0.06241855477982412, Recompensa Acumulada: 12.0
# Episodio: 277, Exploración: 0.06179436923202588, Recompensa Acumulada: 15.0
# Episodio: 278, Exploración: 0.06117642553970562, Recompensa Acumulada: 14.0
# Episodio: 279, Exploración: 0.06056466128430856, Recompensa Acumulada: 17.0
# Episodio: 280, Exploración: 0.05995901467146548, Recompensa Acumulada: 16.0
# Episodio: 281, Exploración: 0.05935942452475082, Recompensa Acumulada: 23.0
# Episodio: 282, Exploración: 0.058765830279503314, Recompensa Acumulada: 52.0
# Episodio: 283, Exploración: 0.05817817197670828, Recompensa Acumulada: 122.0
# Episodio: 284, Exploración: 0.057596390256941195, Recompensa Acumulada: 157.0
# Episodio: 285, Exploración: 0.05702042635437178, Recompensa Acumulada: 13.0
# Episodio: 286, Exploración: 0.05645022209082806, Recompensa Acumulada: 13.0
# Episodio: 287, Exploración: 0.05588571986991978, Recompensa Acumulada: 15.0
# Episodio: 288, Exploración: 0.055326862671220584, Recompensa Acumulada: 15.0
# Episodio: 289, Exploración: 0.05477359404450838, Recompensa Acumulada: 22.0
# Episodio: 290, Exploración: 0.054225858104063294, Recompensa Acumulada: 57.0
# Episodio: 291, Exploración: 0.05368359952302266, Recompensa Acumulada: 122.0
# Episodio: 292, Exploración: 0.053146763527792434, Recompensa Acumulada: 498.0
# Episodio: 293, Exploración: 0.052615295892514506, Recompensa Acumulada: 125.0
# Episodio: 294, Exploración: 0.052089142933589364, Recompensa Acumulada: 99.0
# Episodio: 295, Exploración: 0.05156825150425347, Recompensa Acumulada: 34.0
# Episodio: 296, Exploración: 0.051052568989210935, Recompensa Acumulada: 21.0
# Episodio: 297, Exploración: 0.05054204329931883, Recompensa Acumulada: 21.0
# Episodio: 298, Exploración: 0.05003662286632564, Recompensa Acumulada: 154.0
# Episodio: 299, Exploración: 0.04953625663766238, Recompensa Acumulada: 11.0
# Episodio: 300, Exploración: 0.04904089407128576, Recompensa Acumulada: 10.0
# Episodio: 301, Exploración: 0.0485504851305729, Recompensa Acumulada: 7.0
# Episodio: 302, Exploración: 0.048064980279267165, Recompensa Acumulada: 9.0
# Episodio: 303, Exploración: 0.04758433047647449, Recompensa Acumulada: 10.0
# Episodio: 304, Exploración: 0.04710848717170975, Recompensa Acumulada: 107.0
# Episodio: 305, Exploración: 0.04663740229999265, Recompensa Acumulada: 24.0
# Episodio: 306, Exploración: 0.04617102827699272, Recompensa Acumulada: 20.0
# Episodio: 307, Exploración: 0.045709317994222794, Recompensa Acumulada: 21.0
# Episodio: 308, Exploración: 0.04525222481428057, Recompensa Acumulada: 84.0
# Episodio: 309, Exploración: 0.04479970256613776, Recompensa Acumulada: 79.0
# Episodio: 310, Exploración: 0.04435170554047638, Recompensa Acumulada: 91.0
# Episodio: 311, Exploración: 0.043908188485071616, Recompensa Acumulada: 87.0
# Episodio: 312, Exploración: 0.0434691066002209, Recompensa Acumulada: 59.0
# Episodio: 313, Exploración: 0.04303441553421869, Recompensa Acumulada: 24.0
# Episodio: 314, Exploración: 0.0426040713788765, Recompensa Acumulada: 20.0
# Episodio: 315, Exploración: 0.04217803066508773, Recompensa Acumulada: 13.0
# Episodio: 316, Exploración: 0.04175625035843686, Recompensa Acumulada: 25.0
# Episodio: 317, Exploración: 0.041338687854852486, Recompensa Acumulada: 91.0
# Episodio: 318, Exploración: 0.04092530097630396, Recompensa Acumulada: 131.0
# Episodio: 319, Exploración: 0.040516047966540916, Recompensa Acumulada: 145.0
# Episodio: 320, Exploración: 0.04011088748687551, Recompensa Acumulada: 139.0
# Episodio: 321, Exploración: 0.03970977861200675, Recompensa Acumulada: 112.0
# Episodio: 322, Exploración: 0.03931268082588668, Recompensa Acumulada: 75.0
# Episodio: 323, Exploración: 0.03891955401762781, Recompensa Acumulada: 22.0
# Episodio: 324, Exploración: 0.03853035847745153, Recompensa Acumulada: 12.0
# Episodio: 325, Exploración: 0.03814505489267701, Recompensa Acumulada: 102.0
# Episodio: 326, Exploración: 0.03776360434375024, Recompensa Acumulada: 144.0
# Episodio: 327, Exploración: 0.03738596830031274, Recompensa Acumulada: 107.0
# Episodio: 328, Exploración: 0.03701210861730961, Recompensa Acumulada: 102.0
# Episodio: 329, Exploración: 0.03664198753113651, Recompensa Acumulada: 109.0
# Episodio: 330, Exploración: 0.036275567655825146, Recompensa Acumulada: 131.0
# Episodio: 331, Exploración: 0.03591281197926689, Recompensa Acumulada: 24.0
# Episodio: 332, Exploración: 0.035553683859474224, Recompensa Acumulada: 16.0
# Episodio: 333, Exploración: 0.03519814702087948, Recompensa Acumulada: 12.0
# Episodio: 334, Exploración: 0.03484616555067068, Recompensa Acumulada: 13.0
# Episodio: 335, Exploración: 0.034497703895163975, Recompensa Acumulada: 15.0
# Episodio: 336, Exploración: 0.03415272685621234, Recompensa Acumulada: 130.0
# Episodio: 337, Exploración: 0.03381119958765021, Recompensa Acumulada: 164.0
# Episodio: 338, Exploración: 0.03347308759177371, Recompensa Acumulada: 138.0
# Episodio: 339, Exploración: 0.03313835671585597, Recompensa Acumulada: 161.0
# Episodio: 340, Exploración: 0.03280697314869741, Recompensa Acumulada: 9.0
# Episodio: 341, Exploración: 0.032478903417210436, Recompensa Acumulada: 7.0
# Episodio: 342, Exploración: 0.032154114383038335, Recompensa Acumulada: 8.0
# Episodio: 343, Exploración: 0.03183257323920795, Recompensa Acumulada: 9.0
# Episodio: 344, Exploración: 0.03151424750681587, Recompensa Acumulada: 8.0
# Episodio: 345, Exploración: 0.03119910503174771, Recompensa Acumulada: 10.0
# Episodio: 346, Exploración: 0.030887113981430233, Recompensa Acumulada: 10.0
# Episodio: 347, Exploración: 0.03057824284161593, Recompensa Acumulada: 12.0
# Episodio: 348, Exploración: 0.03027246041319977, Recompensa Acumulada: 17.0
# Episodio: 349, Exploración: 0.029969735809067772, Recompensa Acumulada: 168.0
# Episodio: 350, Exploración: 0.029670038450977095, Recompensa Acumulada: 88.0
# Episodio: 351, Exploración: 0.029373338066467324, Recompensa Acumulada: 36.0
# Episodio: 352, Exploración: 0.02907960468580265, Recompensa Acumulada: 27.0
# Episodio: 353, Exploración: 0.028788808638944622, Recompensa Acumulada: 19.0
# Episodio: 354, Exploración: 0.028500920552555174, Recompensa Acumulada: 39.0
# Episodio: 355, Exploración: 0.028215911347029624, Recompensa Acumulada: 32.0
# Episodio: 356, Exploración: 0.027933752233559327, Recompensa Acumulada: 22.0
# Episodio: 357, Exploración: 0.027654414711223735, Recompensa Acumulada: 24.0
# Episodio: 358, Exploración: 0.027377870564111496, Recompensa Acumulada: 23.0
# Episodio: 359, Exploración: 0.027104091858470382, Recompensa Acumulada: 26.0
# Episodio: 360, Exploración: 0.026833050939885677, Recompensa Acumulada: 21.0
# Episodio: 361, Exploración: 0.02656472043048682, Recompensa Acumulada: 21.0
# Episodio: 362, Exploración: 0.02629907322618195, Recompensa Acumulada: 19.0
# Episodio: 363, Exploración: 0.026036082493920133, Recompensa Acumulada: 97.0
# Episodio: 364, Exploración: 0.02577572166898093, Recompensa Acumulada: 100.0
# Episodio: 365, Exploración: 0.025517964452291122, Recompensa Acumulada: 110.0
# Episodio: 366, Exploración: 0.02526278480776821, Recompensa Acumulada: 112.0
# Episodio: 367, Exploración: 0.025010156959690527, Recompensa Acumulada: 111.0
# Episodio: 368, Exploración: 0.02476005539009362, Recompensa Acumulada: 125.0
# Episodio: 369, Exploración: 0.024512454836192684, Recompensa Acumulada: 112.0
# Episodio: 370, Exploración: 0.024267330287830756, Recompensa Acumulada: 121.0
# Episodio: 371, Exploración: 0.024024656984952448, Recompensa Acumulada: 122.0
# Episodio: 372, Exploración: 0.023784410415102923, Recompensa Acumulada: 107.0
# Episodio: 373, Exploración: 0.023546566310951894, Recompensa Acumulada: 111.0
# Episodio: 374, Exploración: 0.023311100647842375, Recompensa Acumulada: 110.0
# Episodio: 375, Exploración: 0.02307798964136395, Recompensa Acumulada: 127.0
# Episodio: 376, Exploración: 0.022847209744950314, Recompensa Acumulada: 91.0
# Episodio: 377, Exploración: 0.02261873764750081, Recompensa Acumulada: 35.0
# Episodio: 378, Exploración: 0.022392550271025803, Recompensa Acumulada: 26.0
# Episodio: 379, Exploración: 0.022168624768315544, Recompensa Acumulada: 17.0
# Episodio: 380, Exploración: 0.02194693852063239, Recompensa Acumulada: 21.0
# Episodio: 381, Exploración: 0.021727469135426065, Recompensa Acumulada: 104.0
# Episodio: 382, Exploración: 0.021510194444071803, Recompensa Acumulada: 173.0
# Episodio: 383, Exploración: 0.021295092499631085, Recompensa Acumulada: 151.0
# Episodio: 384, Exploración: 0.021082141574634772, Recompensa Acumulada: 128.0
# Episodio: 385, Exploración: 0.020871320158888425, Recompensa Acumulada: 122.0
# Episodio: 386, Exploración: 0.020662606957299542, Recompensa Acumulada: 94.0
# Episodio: 387, Exploración: 0.020455980887726547, Recompensa Acumulada: 119.0
# Episodio: 388, Exploración: 0.02025142107884928, Recompensa Acumulada: 111.0
# Episodio: 389, Exploración: 0.020048906868060788, Recompensa Acumulada: 105.0
# Episodio: 390, Exploración: 0.01984841779938018, Recompensa Acumulada: 115.0
# Episodio: 391, Exploración: 0.019649933621386378, Recompensa Acumulada: 24.0
# Episodio: 392, Exploración: 0.019453434285172513, Recompensa Acumulada: 18.0
# Episodio: 393, Exploración: 0.019258899942320787, Recompensa Acumulada: 106.0
# Episodio: 394, Exploración: 0.01906631094289758, Recompensa Acumulada: 162.0
# Episodio: 395, Exploración: 0.018875647833468602, Recompensa Acumulada: 155.0
# Episodio: 396, Exploración: 0.018686891355133916, Recompensa Acumulada: 140.0
# Episodio: 397, Exploración: 0.018500022441582577, Recompensa Acumulada: 142.0
# Episodio: 398, Exploración: 0.01831502221716675, Recompensa Acumulada: 144.0
# Episodio: 399, Exploración: 0.018131871994995084, Recompensa Acumulada: 124.0
# Episodio: 400, Exploración: 0.017950553275045134, Recompensa Acumulada: 126.0
# Episodio: 401, Exploración: 0.017771047742294682, Recompensa Acumulada: 147.0
# Episodio: 402, Exploración: 0.017593337264871736, Recompensa Acumulada: 136.0
# Episodio: 403, Exploración: 0.01741740389222302, Recompensa Acumulada: 122.0
# Episodio: 404, Exploración: 0.01724322985330079, Recompensa Acumulada: 162.0
# Episodio: 405, Exploración: 0.017070797554767782, Recompensa Acumulada: 141.0
# Episodio: 406, Exploración: 0.016900089579220106, Recompensa Acumulada: 147.0
# Episodio: 407, Exploración: 0.016731088683427906, Recompensa Acumulada: 172.0
# Episodio: 408, Exploración: 0.016563777796593626, Recompensa Acumulada: 189.0
# Episodio: 409, Exploración: 0.016398140018627688, Recompensa Acumulada: 7.0
# Episodio: 410, Exploración: 0.01623415861844141, Recompensa Acumulada: 6.0
# Episodio: 411, Exploración: 0.016071817032256998, Recompensa Acumulada: 10.0
# Episodio: 412, Exploración: 0.01591109886193443, Recompensa Acumulada: 9.0
# Episodio: 413, Exploración: 0.015751987873315085, Recompensa Acumulada: 51.0
# Episodio: 414, Exploración: 0.015594467994581935, Recompensa Acumulada: 14.0
# Episodio: 415, Exploración: 0.015438523314636115, Recompensa Acumulada: 11.0
# Episodio: 416, Exploración: 0.015284138081489753, Recompensa Acumulada: 11.0
# Episodio: 417, Exploración: 0.015131296700674856, Recompensa Acumulada: 11.0
# Episodio: 418, Exploración: 0.014979983733668108, Recompensa Acumulada: 13.0
# Episodio: 419, Exploración: 0.014830183896331426, Recompensa Acumulada: 15.0
# Episodio: 420, Exploración: 0.014681882057368112, Recompensa Acumulada: 18.0
# Episodio: 421, Exploración: 0.01453506323679443, Recompensa Acumulada: 101.0
# Episodio: 422, Exploración: 0.014389712604426485, Recompensa Acumulada: 494.0
# Episodio: 423, Exploración: 0.01424581547838222, Recompensa Acumulada: 245.0
# Episodio: 424, Exploración: 0.014103357323598397, Recompensa Acumulada: 330.0
# Episodio: 425, Exploración: 0.013962323750362413, Recompensa Acumulada: 182.0
# Episodio: 426, Exploración: 0.013822700512858789, Recompensa Acumulada: 247.0
# Episodio: 427, Exploración: 0.0136844735077302, Recompensa Acumulada: 24.0
# Episodio: 428, Exploración: 0.013547628772652899, Recompensa Acumulada: 18.0
# Episodio: 429, Exploración: 0.01341215248492637, Recompensa Acumulada: 185.0
# Episodio: 430, Exploración: 0.013278030960077106, Recompensa Acumulada: 221.0
# Episodio: 431, Exploración: 0.013145250650476335, Recompensa Acumulada: 151.0
# Episodio: 432, Exploración: 0.01301379814397157, Recompensa Acumulada: 139.0
# Episodio: 433, Exploración: 0.012883660162531854, Recompensa Acumulada: 194.0
# Episodio: 434, Exploración: 0.012754823560906535, Recompensa Acumulada: 128.0
# Episodio: 435, Exploración: 0.01262727532529747, Recompensa Acumulada: 156.0
# Episodio: 436, Exploración: 0.012501002572044496, Recompensa Acumulada: 146.0
# Episodio: 437, Exploración: 0.01237599254632405, Recompensa Acumulada: 138.0
# Episodio: 438, Exploración: 0.01225223262086081, Recompensa Acumulada: 139.0
# Episodio: 439, Exploración: 0.012129710294652202, Recompensa Acumulada: 136.0
# Episodio: 440, Exploración: 0.01200841319170568, Recompensa Acumulada: 139.0
# Episodio: 441, Exploración: 0.011888329059788623, Recompensa Acumulada: 129.0
# Episodio: 442, Exploración: 0.011769445769190737, Recompensa Acumulada: 132.0
# Episodio: 443, Exploración: 0.01165175131149883, Recompensa Acumulada: 130.0
# Episodio: 444, Exploración: 0.011535233798383842, Recompensa Acumulada: 148.0
# Episodio: 445, Exploración: 0.011419881460400004, Recompensa Acumulada: 151.0
# Episodio: 446, Exploración: 0.011305682645796004, Recompensa Acumulada: 137.0
# Episodio: 447, Exploración: 0.011192625819338045, Recompensa Acumulada: 136.0
# Episodio: 448, Exploración: 0.011080699561144665, Recompensa Acumulada: 145.0
# Episodio: 449, Exploración: 0.010969892565533218, Recompensa Acumulada: 133.0
# Episodio: 450, Exploración: 0.010860193639877886, Recompensa Acumulada: 154.0
# Episodio: 451, Exploración: 0.010751591703479106, Recompensa Acumulada: 145.0
# Episodio: 452, Exploración: 0.010644075786444315, Recompensa Acumulada: 137.0
# Episodio: 453, Exploración: 0.010537635028579873, Recompensa Acumulada: 146.0
# Episodio: 454, Exploración: 0.010432258678294073, Recompensa Acumulada: 150.0
# Episodio: 455, Exploración: 0.010327936091511133, Recompensa Acumulada: 138.0
# Episodio: 456, Exploración: 0.010224656730596022, Recompensa Acumulada: 155.0
# Episodio: 457, Exploración: 0.01012241016329006, Recompensa Acumulada: 134.0
# Episodio: 458, Exploración: 0.01002118606165716, Recompensa Acumulada: 153.0
# Episodio: 459, Exploración: 0.01, Recompensa Acumulada: 160.0
# Episodio: 460, Exploración: 0.01, Recompensa Acumulada: 159.0
# Episodio: 461, Exploración: 0.01, Recompensa Acumulada: 157.0
# Episodio: 462, Exploración: 0.01, Recompensa Acumulada: 185.0
# Episodio: 463, Exploración: 0.01, Recompensa Acumulada: 156.0
# Episodio: 464, Exploración: 0.01, Recompensa Acumulada: 137.0
# Episodio: 465, Exploración: 0.01, Recompensa Acumulada: 178.0
# Episodio: 466, Exploración: 0.01, Recompensa Acumulada: 192.0
# Episodio: 467, Exploración: 0.01, Recompensa Acumulada: 181.0
# Episodio: 468, Exploración: 0.01, Recompensa Acumulada: 173.0
# Episodio: 469, Exploración: 0.01, Recompensa Acumulada: 181.0
# Episodio: 470, Exploración: 0.01, Recompensa Acumulada: 187.0
# Episodio: 471, Exploración: 0.01, Recompensa Acumulada: 280.0
# Episodio: 472, Exploración: 0.01, Recompensa Acumulada: 8.0
# Episodio: 473, Exploración: 0.01, Recompensa Acumulada: 40.0
# Episodio: 474, Exploración: 0.01, Recompensa Acumulada: 136.0
# Episodio: 475, Exploración: 0.01, Recompensa Acumulada: 247.0
# Episodio: 476, Exploración: 0.01, Recompensa Acumulada: 234.0
# Episodio: 477, Exploración: 0.01, Recompensa Acumulada: 285.0
# Episodio: 478, Exploración: 0.01, Recompensa Acumulada: 288.0
# Episodio: 479, Exploración: 0.01, Recompensa Acumulada: 290.0
# Episodio: 480, Exploración: 0.01, Recompensa Acumulada: 282.0
# Episodio: 481, Exploración: 0.01, Recompensa Acumulada: 258.0
# Episodio: 482, Exploración: 0.01, Recompensa Acumulada: 193.0
# Episodio: 483, Exploración: 0.01, Recompensa Acumulada: 202.0
# Episodio: 484, Exploración: 0.01, Recompensa Acumulada: 247.0
# Episodio: 485, Exploración: 0.01, Recompensa Acumulada: 289.0
# Episodio: 486, Exploración: 0.01, Recompensa Acumulada: 233.0
# Episodio: 487, Exploración: 0.01, Recompensa Acumulada: 335.0
# Episodio: 488, Exploración: 0.01, Recompensa Acumulada: 30.0
# Episodio: 489, Exploración: 0.01, Recompensa Acumulada: 14.0
# Episodio: 490, Exploración: 0.01, Recompensa Acumulada: 8.0
# Episodio: 491, Exploración: 0.01, Recompensa Acumulada: 327.0
# Episodio: 492, Exploración: 0.01, Recompensa Acumulada: 195.0
# Episodio: 493, Exploración: 0.01, Recompensa Acumulada: 181.0
# Episodio: 494, Exploración: 0.01, Recompensa Acumulada: 277.0
# Episodio: 495, Exploración: 0.01, Recompensa Acumulada: 355.0
# Episodio: 496, Exploración: 0.01, Recompensa Acumulada: 498.0
# Episodio: 497, Exploración: 0.01, Recompensa Acumulada: 382.0
# Episodio: 498, Exploración: 0.01, Recompensa Acumulada: 322.0
# Episodio: 499, Exploración: 0.01, Recompensa Acumulada: 498.0

# %%
plotting.plot_episode_stats(stats, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)
